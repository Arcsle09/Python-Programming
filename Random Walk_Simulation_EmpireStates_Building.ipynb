# %%
#Random Walk Simulations 

import matplotlib.pyplot as plt
import numpy as np
np.random.seed(123)
all_walks = []

# Simulate random walk 250 times
for i in range(100) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)

        # Implement clumsiness
        if np.random.rand() <= 0.001 :
            step = 0

        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))
plt.plot(np_aw_t)
plt.show()

# %%
#build a function with flexible arguments 
#please note that, in python, if we need to do addition of list element, it can not happen using += operator. 
#Instead, += will append the elements into list. 
def sum_all_num(*args):
        summ = []
        for i in args:
            summ += i  
        return summ

# %%
sum_all_num([34,32,21,56,45,323423])
# Out:
# [34, 32, 21, 56, 45, 323423]

# %%
map(sum,[34,2,32])
